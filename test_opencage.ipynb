# %% [markdown]
# While I migrated this away from a notebook into `.py` files, I am seeing that notebooks do have their benefit :). It remembers the output of chunks of code and you can annotate it with Markdown, and you can choose to run only one cell at a time.
#
# Of course, if you need a script to be able to run, then I don't think notebooks are the right thing for the job, but I'm starting to grow fond of them.

# %% [markdown]
# Before we actually work with OpenCage, let's see what the requests return, and how we can tweak it

# %%
from opencage.geocoder import OpenCageGeocode
import dotenv
import os
dotenv.load_dotenv()
KEY = os.getenv('OPENCAGE')
geocoder = OpenCageGeocode(KEY)

# %% [markdown]
# First, let's have some actual addresses to test it with.

# %%
addr1 = '83 MOUNT VERNON ST'

addr2 = """FOREST HILLS ST & GLEN RD
JAMAICA PLAIN, MA 02130
UNITED STATES"""

# The current script chops the addresses, unfortunately
addr2_chopped = "FOREST HILLS ST & GLEN RD"

addr3 = """ARUNDEL ST & MOUNTFORT ST
BOSTON, MA 02215
UNITED STATES
"""

addr3_chopped = "ARUNDEL ST & MOUNTFORT ST"

# %% [markdown]
# We can try "just geocoding it"

# %%
geocoder.geocode(addr1)
# Out:
# [{'annotations': {'DMS': {'lat': "42° 21' 30.46608'' N",
#     'lng': "71° 4' 2.47872'' W"},
#    'FIPS': {'county': '25025', 'state': '25'},
#    'MGRS': '19TCG2974791647',
#    'Maidenhead': 'FN42li16wa',
#    'Mercator': {'x': -7911181.794, 'y': 5186030.125},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=405903359#map=17/42.35846/-71.06736',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=17/42.35846/-71.06736&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=42.35846&mlon=-71.06736#map=17/42.35846/-71.06736'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': 'drt2yz47ftg0v42mzx3r',
#    'qibla': 60.42,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Mount Vernon Street',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1683106680,
#      'astronomical': 1683100080,
#      'civil': 1683104820,
#      'nautical': 1683102540},
#     'set': {'apparent': 1683157500,
#      'astronomical': 1683077760,
#      'civil': 1683072960,
#      'nautical': 1683075240}},
#    'timezone': {'name': 'America/New_York',
#     'now_in_dst': 1,
#     'offset_sec': -14400,
#     'offset_string': '-0400',
#     'short_name': 'EDT'},
#    'what3words': {'words': 'burst.behave.tummy'}},
#   'bounds': {'northeast': {'lat': 42.3585968, 'lng': -71.0672842},
#    'southwest': {'lat': 42.3583318, 'lng': -71.0674175}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Boston',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Suffolk County',
#    'house_number': '83',
#    'postcode': '02108',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'suburb': 'Beacon Hill'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Boston, MA 02108, United States of America',
#   'geometry': {'lat': 42.3584628, 'lng': -71.0673552}},
#  {'annotations': {'DMS': {'lat': "41° 39' 7.29432'' N",
#     'lng': "70° 56' 24.43452'' W"},
#    'FIPS': {'county': '25005', 'state': '25'},
#    'MGRS': '19TCG3844712960',
#    'Maidenhead': 'FN41mp76el',
#    'Mercator': {'x': -7897018.116, 'y': 5080591.236},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=214696462#map=17/41.65203/-70.94012',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=17/41.65203/-70.94012&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=41.65203&mlon=-70.94012#map=17/41.65203/-70.94012'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': 'drmscwwbxkkn65e7rkx3',
#    'qibla': 60.51,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Mount Vernon Street',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1683106740,
#      'astronomical': 1683100260,
#      'civil': 1683104940,
#      'nautical': 1683102720},
#     'set': {'apparent': 1683157380,
#      'astronomical': 1683077520,
#      'civil': 1683072780,
#      'nautical': 1683075060}},
#    'timezone': {'name': 'America/New_York',
#     'now_in_dst': 1,
#     'offset_sec': -14400,
#     'offset_string': '-0400',
#     'short_name': 'EDT'},
#    'what3words': {'words': 'hang.lost.cliff'}},
#   'bounds': {'northeast': {'lat': 41.6520829, 'lng': -70.9400616},
#    'southwest': {'lat': 41.6519695, 'lng': -70.9401799}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'New Bedford',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Bristol County',
#    'house_number': '83',
#    'postcode': '02746',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, New Bedford, MA 02746, United States of America',
#   'geometry': {'lat': 41.6520262, 'lng': -70.9401207}},
#  {'annotations': {'DMS': {'lat': "42° 22' 57.48456'' N",
#     'lng': "71° 4' 54.14088'' W"},
#    'FIPS': {'county': '25017', 'state': '25'},
#    'MGRS': '19TCG2863194360',
#    'Maidenhead': 'FN42lj01et',
#    'Mercator': {'x': -7912779.3, 'y': 5189658.88},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=29794399#map=17/42.38263/-71.08171',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=17/42.38263/-71.08171&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=42.38263&mlon=-71.08171#map=17/42.38263/-71.08171'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': 'drt3n7xbspwx1x37hey3',
#    'qibla': 60.41,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Mount Vernon Street',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1683106680,
#      'astronomical': 1683100080,
#      'civil': 1683104820,
#      'nautical': 1683102540},
#     'set': {'apparent': 1683157500,
#      'astronomical': 1683077760,
#      'civil': 1683072960,
#      'nautical': 1683075240}},
#    'timezone': {'name': 'America/New_York',
#     'now_in_dst': 1,
#     'offset_sec': -14400,
#     'offset_string': '-0400',
#     'short_name': 'EDT'},
#    'what3words': {'words': 'axed.chair.shins'}},
#   'bounds': {'northeast': {'lat': 42.3827027, 'lng': -71.0815971},
#    'southwest': {'lat': 42.3825666, 'lng': -71.0818146}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Somerville',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Middlesex County',
#    'house_number': '83',
#    'neighbourhood': 'Inner Belt',
#    'postcode': '02145',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Somerville, MA 02145, United States of America',
#   'geometry': {'lat': 42.3826346, 'lng': -71.0817058}},
#  {'annotations': {'DMS': {'lat': "42° 25' 55.59276'' N",
#     'lng': "71° 3' 45.44532'' W"},
#    'FIPS': {'county': '25017', 'state': '25'},
#    'MGRS': '19TCG3033599815',
#    'Maidenhead': 'FN42lk23lq',
#    'Mercator': {'x': -7910655.081, 'y': 5197090.546},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=29802935#map=17/42.43211/-71.06262',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=17/42.43211/-71.06262&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=42.43211&mlon=-71.06262#map=17/42.43211/-71.06262'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': 'drt3qutbby7mb44zjq0d',
#    'qibla': 60.43,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Mount Vernon Street',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1683106680,
#      'astronomical': 1683100080,
#      'civil': 1683104820,
#      'nautical': 1683102540},
#     'set': {'apparent': 1683157500,
#      'astronomical': 1683077760,
#      'civil': 1683072960,
#      'nautical': 1683075240}},
#    'timezone': {'name': 'America/New_York',
#     'now_in_dst': 1,
#     'offset_sec': -14400,
#     'offset_string': '-0400',
#     'short_name': 'EDT'},
#    'what3words': {'words': 'common.upper.fines'}},
#   'bounds': {'northeast': {'lat': 42.4321696, 'lng': -71.062526},
#    'southwest': {'lat': 42.4320484, 'lng': -71.0627213}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Middlesex County',
#    'hamlet': 'Malden Centre',
#    'house_number': '83',
#    'neighbourhood': 'Bryant Terrace Apartments',
#    'postcode': '02148',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'town': 'Malden'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Malden Centre, Malden, MA 02148, United States of America',
#   'geometry': {'lat': 42.4321091, 'lng': -71.0626237}},
#  {'annotations': {'DMS': {'lat': "42° 26' 57.70392'' N",
#     'lng': "71° 3' 50.34528'' W"},
#    'FIPS': {'county': '25017', 'state': '25'},
#    'MGRS': '19TCH3027001734',
#    'Maidenhead': 'FN42lk27hu',
#    'Mercator': {'x': -7910806.603, 'y': 5199683.569},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=29654347#map=17/42.44936/-71.06398',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=17/42.44936/-71.06398&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=42.44936&mlon=-71.06398#map=17/42.44936/-71.06398'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': 'drt3qzsv3nskf5b0ux1e',
#    'qibla': 60.43,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Mount Vernon Street',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1683106680,
#      'astronomical': 1683100020,
#      'civil': 1683104820,
#      'nautical': 1683102540},
#     'set': {'apparent': 1683157500,
#      'astronomical': 1683077760,
#      'civil': 1683072960,
#      'nautical': 1683075240}},
#    'timezone': {'name': 'America/New_York',
#     'now_in_dst': 1,
#     'offset_sec': -14400,
#     'offset_string': '-0400',
#     'short_name': 'EDT'},
#    'what3words': {'words': 'trendy.union.hidden'}},
#   'bounds': {'northeast': {'lat': 42.4494482, 'lng': -71.0638819},
#    'southwest': {'lat': 42.4492763, 'lng': -71.0640877}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Middlesex County',
#    'hamlet': 'Wyoming',
#    'house_number': '83',
#    'postcode': '02176',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'town': 'Melrose'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Wyoming, Melrose, MA 02176, United States of America',
#   'geometry': {'lat': 42.4493622, 'lng': -71.0639848}},
#  {'annotations': {'DMS': {'lat': "42° 38' 48.53400'' N",
#     'lng': "71° 19' 33.48696'' W"},
#    'FIPS': {'county': '25017', 'state': '25'},
#    'MGRS': '19TCH0932724218',
#    'Maidenhead': 'FN42ip05vf',
#    'Mercator': {'x': -7939970.509, 'y': 5229410.689},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=214331804#map=17/42.64682/-71.32597',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=17/42.64682/-71.32597&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=42.64682&mlon=-71.32597#map=17/42.64682/-71.32597'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': 'drt68gw58qx08q7hhmdt',
#    'qibla': 60.25,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Mount Vernon Street',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1683106680,
#      'astronomical': 1683100080,
#      'civil': 1683104820,
#      'nautical': 1683102540},
#     'set': {'apparent': 1683157620,
#      'astronomical': 1683077880,
#      'civil': 1683073080,
#      'nautical': 1683075360}},
#    'timezone': {'name': 'America/New_York',
#     'now_in_dst': 1,
#     'offset_sec': -14400,
#     'offset_string': '-0400',
#     'short_name': 'EDT'},
#    'what3words': {'words': 'stores.rocket.basket'}},
#   'bounds': {'northeast': {'lat': 42.6468908, 'lng': -71.3258307},
#    'southwest': {'lat': 42.6467307, 'lng': -71.326068}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Lowell',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Middlesex County',
#    'house_number': '81;83',
#    'neighbourhood': 'Cambodia Town',
#    'postcode': '01854',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'suburb': 'The Acre'},
#   'confidence': 10,
#   'formatted': '81;83 Mount Vernon Street, Lowell, MA 01854, United States of America',
#   'geometry': {'lat': 42.646815, 'lng': -71.3259686}},
#  {'annotations': {'DMS': {'lat': "32° 10' 46.32924'' N",
#     'lng': "82° 35' 42.93168'' W"},
#    'FIPS': {'county': '13209', 'state': '13'},
#    'MGRS': '17SLR4960561451',
#    'Maidenhead': 'EM82qe83nc',
#    'Mercator': {'x': -9194462.153, 'y': 3764146.57},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=9398332#map=17/32.17954/-82.59526',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=17/32.17954/-82.59526&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=32.17954&mlon=-82.59526#map=17/32.17954/-82.59526'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': 'djtr06pgqur0yvexd8c1',
#    'qibla': 53.81,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Mount Vernon Street',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1683110580,
#      'astronomical': 1683105180,
#      'civil': 1683109020,
#      'nautical': 1683107160},
#     'set': {'apparent': 1683072720,
#      'astronomical': 1683078120,
#      'civil': 1683074280,
#      'nautical': 1683076140}},
#    'timezone': {'name': 'America/New_York',
#     'now_in_dst': 1,
#     'offset_sec': -14400,
#     'offset_string': '-0400',
#     'short_name': 'EDT'},
#    'what3words': {'words': 'unarmed.stat.parcels'}},
#   'bounds': {'northeast': {'lat': 32.1795859, 'lng': -82.5952088},
#    'southwest': {'lat': 32.1794859, 'lng': -82.5953088}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-GA'],
#    '_category': 'building',
#    '_type': 'building',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Montgomery County',
#    'house_number': '83',
#    'postcode': '30445',
#    'road': 'Mount Vernon Street',
#    'state': 'Georgia',
#    'state_code': 'GA',
#    'village': 'Mount Vernon'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Mount Vernon, Montgomery County, GA 30445, United States of America',
#   'geometry': {'lat': 32.1795359, 'lng': -82.5952588}},
#  {'annotations': {'DMS': {'lat': "42° 22' 33.94308'' N",
#     'lng': "83° 4' 33.75480'' W"},
#    'FIPS': {'county': '26163', 'state': '26'},
#    'MGRS': '17TLG2907993622',
#    'Maidenhead': 'EN82lj00vg',
#    'Mercator': {'x': -9247982.805, 'y': 5188677.034},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=8763540#map=17/42.37610/-83.07604',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=17/42.37610/-83.07604&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=42.37610&mlon=-83.07604#map=17/42.37610/-83.07604'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': 'dpscjd3feusw95fqhkdw',
#    'qibla': 52,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Mount Vernon Street',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1683109560,
#      'astronomical': 1683102960,
#      'civil': 1683107700,
#      'nautical': 1683105420},
#     'set': {'apparent': 1683073980,
#      'astronomical': 1683080640,
#      'civil': 1683075840,
#      'nautical': 1683078120}},
#    'timezone': {'name': 'America/Detroit',
#     'now_in_dst': 1,
#     'offset_sec': -14400,
#     'offset_string': '-0400',
#     'short_name': 'EDT'},
#    'what3words': {'words': 'kind.metro.branded'}},
#   'bounds': {'northeast': {'lat': 42.3761453, 'lng': -83.075993},
#    'southwest': {'lat': 42.3760453, 'lng': -83.076093}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MI'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Detroit',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Wayne County',
#    'house_number': '83',
#    'neighbourhood': 'North End',
#    'postcode': '48202',
#    'road': 'Mount Vernon Street',
#    'state': 'Michigan',
#    'state_code': 'MI',
#    'suburb': 'New Center'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Detroit, MI 48202, United States of America',
#   'geometry': {'lat': 42.3760953, 'lng': -83.076043}},
#  {'annotations': {'DMS': {'lat': "42° 16' 34.07376'' N",
#     'lng': "71° 47' 16.71108'' W"},
#    'FIPS': {'county': '25027', 'state': '25'},
#    'MGRS': '19TBG7009884199',
#    'Maidenhead': 'FN42cg56kg',
#    'Mercator': {'x': -7991400.852, 'y': 5173680.815},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=9605155#map=17/42.27613/-71.78798',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=17/42.27613/-71.78798&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=42.27613&mlon=-71.78798#map=17/42.27613/-71.78798'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'NORTHERN_AMERICA': '021',
#      'US': '840',
#      'WORLD': '001'},
#     'statistical_groupings': ['MEDC']},
#    'callingcode': 1,
#    'currency': {'alternate_symbols': ['US$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'US$',
#     'html_entity': '$',
#     'iso_code': 'USD',
#     'iso_numeric': '840',
#     'name': 'United States Dollar',
#     'smallest_denomination': 1,
#     'subunit': 'Cent',
#     'subunit_to_unit': 100,
#     'symbol': '$',
#     'symbol_first': 1,
#     'thousands_separator': ','},
#    'flag': '🇺🇸',
#    'geohash': 'drsbw2js6fjguvg02yu3',
#    'qibla': 59.94,
#    'roadinfo': {'drive_on': 'right',
#     'road': 'Mount Vernon Street',
#     'speed_in': 'mph'},
#    'sun': {'rise': {'apparent': 1683106860,
#      'astronomical': 1683100260,
#      'civil': 1683105000,
#      'nautical': 1683102780},
#     'set': {'apparent': 1683157680,
#      'astronomical': 1683077880,
#      'civil': 1683073080,
#      'nautical': 1683075360}},
#    'timezone': {'name': 'America/New_York',
#     'now_in_dst': 1,
#     'offset_sec': -14400,
#     'offset_string': '-0400',
#     'short_name': 'EDT'},
#    'what3words': {'words': 'factor.remit.orders'}},
#   'bounds': {'northeast': {'lat': 42.2761816, 'lng': -71.7879253},
#    'southwest': {'lat': 42.2760816, 'lng': -71.7880253}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Worcester',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Worcester County',
#    'hamlet': 'Chandler Hill',
#    'house_number': '83',
#    'neighbourhood': 'Lincoln Square',
#    'postcode': '01605',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Chandler Hill, Worcester, MA 01605, United States of America',
#   'geometry': {'lat': 42.2761316, 'lng': -71.7879753}},
#  {'annotations': {'DMS': {'lat': "1° 0' 0.00000'' N",
#     'lng': "7° 0' 0.00000'' E"},
#    'MGRS': '32NKG7743810597',
#    'Maidenhead': 'JJ31ma00aa',
#    'Mercator': {'x': 779236.436, 'y': 110579.965},
#    'OSM': {'note_url': 'https://www.openstreetmap.org/note/new#map=17/1.00000/7.00000&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=1.00000&mlon=7.00000#map=17/1.00000/7.00000'},
#    'UN_M49': {'regions': {'AFRICA': '002',
#      'MIDDLE_AFRICA': '017',
#      'ST': '678',
#      'SUB-SAHARAN_AFRICA': '202',
#      'WORLD': '001'},
#     'statistical_groupings': ['LDC', 'LEDC', 'SIDS']},
#    'callingcode': 239,
#    'currency': {'alternate_symbols': [],
#     'decimal_mark': '.',
#     'format': '%n %u',
#     'html_entity': '',
#     'iso_code': 'STD',
#     'iso_numeric': '678',
#     'name': 'São Tomé and Príncipe Dobra',
#     'smallest_denomination': 10000,
#     'subunit': 'Cêntimo',
#     'subunit_to_unit': 100,
#     'symbol': 'Db',
#     'symbol_first': 0,
#     'thousands_separator': ','},
#    'flag': '🇸🇹',
#    'geohash': 's0hvxq11rvd23gqs46ze',
#    'qibla': 55.14,
#    'roadinfo': {'drive_on': 'right', 'speed_in': 'km/h'},
#    'sun': {'rise': {'apparent': 1683091500,
#      'astronomical': 1683087240,
#      'civil': 1683090240,
#      'nautical': 1683088740},
#     'set': {'apparent': 1683135120,
#      'astronomical': 1683139440,
#      'civil': 1683136440,
#      'nautical': 1683137940}},
#    'timezone': {'name': 'Africa/Sao_Tome',
#     'now_in_dst': 0,
#     'offset_sec': 0,
#     'offset_string': '+0000',
#     'short_name': 'GMT'},
#    'what3words': {'words': 'constructively.exceedingly.supermarkets'}},
#   'bounds': {'northeast': {'lat': 2.242748, 'lng': 9.0},
#    'southwest': {'lat': -1.012878, 'lng': 4.5}},
#   'components': {'ISO_3166-1_alpha-2': 'ST',
#    'ISO_3166-1_alpha-3': 'STP',
#    '_category': 'place',
#    '_type': 'country',
#    'continent': 'Africa',
#    'country': 'São Tomé and Príncipe',
#    'country_code': 'st'},
#   'confidence': 1,
#   'formatted': 'São Tomé and Príncipe',
#   'geometry': {'lat': 1.0, 'lng': 7.0}}]

# %% [markdown]
# It returned quite a lot, including first the MA address, but then also Detroit and even other countries!
#
# Easiest thing to do is to filter by country.
#
# We can also try removing the annotations:
#
# >  If you do not need the information provided in the annotations please set no_annotations=1.
# > This enables us to do less work and significantly reduces the response size and thus reply more quickly.
#
# *API reference*: <https://opencagedata.com/api>. It includes a "best practices" section

# %%
geocoder.geocode(addr1, countrycode='us', no_annotations=1) # unfortunately there is no autocompletion or documentation within Python
# Out:
# [{'bounds': {'northeast': {'lat': 42.3585968, 'lng': -71.0672842},
#    'southwest': {'lat': 42.3583318, 'lng': -71.0674175}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Boston',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Suffolk County',
#    'house_number': '83',
#    'postcode': '02108',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'suburb': 'Beacon Hill'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Boston, MA 02108, United States of America',
#   'geometry': {'lat': 42.3584628, 'lng': -71.0673552}},
#  {'bounds': {'northeast': {'lat': 41.6520829, 'lng': -70.9400616},
#    'southwest': {'lat': 41.6519695, 'lng': -70.9401799}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'New Bedford',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Bristol County',
#    'house_number': '83',
#    'postcode': '02746',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, New Bedford, MA 02746, United States of America',
#   'geometry': {'lat': 41.6520262, 'lng': -70.9401207}},
#  {'bounds': {'northeast': {'lat': 42.3827027, 'lng': -71.0815971},
#    'southwest': {'lat': 42.3825666, 'lng': -71.0818146}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Somerville',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Middlesex County',
#    'house_number': '83',
#    'neighbourhood': 'Inner Belt',
#    'postcode': '02145',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Somerville, MA 02145, United States of America',
#   'geometry': {'lat': 42.3826346, 'lng': -71.0817058}},
#  {'bounds': {'northeast': {'lat': 42.4321696, 'lng': -71.062526},
#    'southwest': {'lat': 42.4320484, 'lng': -71.0627213}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Middlesex County',
#    'hamlet': 'Malden Centre',
#    'house_number': '83',
#    'neighbourhood': 'Bryant Terrace Apartments',
#    'postcode': '02148',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'town': 'Malden'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Malden Centre, Malden, MA 02148, United States of America',
#   'geometry': {'lat': 42.4321091, 'lng': -71.0626237}},
#  {'bounds': {'northeast': {'lat': 42.4494482, 'lng': -71.0638819},
#    'southwest': {'lat': 42.4492763, 'lng': -71.0640877}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Middlesex County',
#    'hamlet': 'Wyoming',
#    'house_number': '83',
#    'postcode': '02176',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'town': 'Melrose'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Wyoming, Melrose, MA 02176, United States of America',
#   'geometry': {'lat': 42.4493622, 'lng': -71.0639848}},
#  {'bounds': {'northeast': {'lat': 42.6468908, 'lng': -71.3258307},
#    'southwest': {'lat': 42.6467307, 'lng': -71.326068}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Lowell',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Middlesex County',
#    'house_number': '81;83',
#    'neighbourhood': 'Cambodia Town',
#    'postcode': '01854',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'suburb': 'The Acre'},
#   'confidence': 10,
#   'formatted': '81;83 Mount Vernon Street, Lowell, MA 01854, United States of America',
#   'geometry': {'lat': 42.646815, 'lng': -71.3259686}},
#  {'bounds': {'northeast': {'lat': 32.1795859, 'lng': -82.5952088},
#    'southwest': {'lat': 32.1794859, 'lng': -82.5953088}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-GA'],
#    '_category': 'building',
#    '_type': 'building',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Montgomery County',
#    'house_number': '83',
#    'postcode': '30445',
#    'road': 'Mount Vernon Street',
#    'state': 'Georgia',
#    'state_code': 'GA',
#    'village': 'Mount Vernon'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Mount Vernon, Montgomery County, GA 30445, United States of America',
#   'geometry': {'lat': 32.1795359, 'lng': -82.5952588}},
#  {'bounds': {'northeast': {'lat': 42.3761453, 'lng': -83.075993},
#    'southwest': {'lat': 42.3760453, 'lng': -83.076093}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MI'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Detroit',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Wayne County',
#    'house_number': '83',
#    'neighbourhood': 'North End',
#    'postcode': '48202',
#    'road': 'Mount Vernon Street',
#    'state': 'Michigan',
#    'state_code': 'MI',
#    'suburb': 'New Center'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Detroit, MI 48202, United States of America',
#   'geometry': {'lat': 42.3760953, 'lng': -83.076043}},
#  {'bounds': {'northeast': {'lat': 42.2761816, 'lng': -71.7879253},
#    'southwest': {'lat': 42.2760816, 'lng': -71.7880253}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Worcester',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Worcester County',
#    'hamlet': 'Chandler Hill',
#    'house_number': '83',
#    'neighbourhood': 'Lincoln Square',
#    'postcode': '01605',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Chandler Hill, Worcester, MA 01605, United States of America',
#   'geometry': {'lat': 42.2761316, 'lng': -71.7879753}}]

# %% [markdown]
# The convenient OSM link is now gone. I guess we can use annotations as we figure out how to use this.

# %% [markdown]
# The places returned in order were:
# * Boston, MA
# * New Bedford, MA
# * Somerville, MA
# * Malden, MA
# * Melrose, MA
# * Lowell, MA
# * Mount Vernon, GA
# * Detroit, MI
# * Worcester, MA
#
# That is quite a lot of them!
#
# What Eric did is to just append Boston, MA to it, and to always use the first result:

# %%
def clean_address(addr):
    return addr.strip() + ", Boston, MA"

clean_address(addr1)
# Out:
# '83 MOUNT VERNON ST, Boston, MA'

# %% [markdown]
# So we can try again:

# %%
geocoder.geocode(clean_address(addr1), countrycode='us', no_annotations=1)
# Out:
# [{'bounds': {'northeast': {'lat': 42.3585968, 'lng': -71.0672842},
#    'southwest': {'lat': 42.3583318, 'lng': -71.0674175}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Boston',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Suffolk County',
#    'house_number': '83',
#    'postcode': '02108',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'suburb': 'Beacon Hill'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Boston, MA 02108, United States of America',
#   'geometry': {'lat': 42.3584628, 'lng': -71.0673552}},
#  {'bounds': {'northeast': {'lat': 42.37483, 'lng': -71.0580528},
#    'southwest': {'lat': 42.37473, 'lng': -71.0581528}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Boston',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Suffolk County',
#    'house_number': '83',
#    'postcode': '02129',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'suburb': 'Charlestown'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Boston, MA 02129, United States of America',
#   'geometry': {'lat': 42.37478, 'lng': -71.0581028}},
#  {'bounds': {'northeast': {'lat': 42.3473889, 'lng': -71.1567504},
#    'southwest': {'lat': 42.3472889, 'lng': -71.1568504}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Boston',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Suffolk County',
#    'house_number': '83',
#    'neighbourhood': 'Brighton Center',
#    'postcode': '02135',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'suburb': 'Brighton'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Boston, MA 02135, United States of America',
#   'geometry': {'lat': 42.3473389, 'lng': -71.1568004}},
#  {'bounds': {'northeast': {'lat': 42.2850204, 'lng': -71.1600453},
#    'southwest': {'lat': 42.2849204, 'lng': -71.1601453}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Boston',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Suffolk County',
#    'house_number': '83',
#    'neighbourhood': 'Highland',
#    'postcode': '02132',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'suburb': 'West Roxbury'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Boston, MA 02132, United States of America',
#   'geometry': {'lat': 42.2849704, 'lng': -71.1600953}},
#  {'bounds': {'northeast': {'lat': 42.3215879, 'lng': -71.0561375},
#    'southwest': {'lat': 42.3214879, 'lng': -71.0562375}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'building',
#    '_type': 'building',
#    'city': 'Boston',
#    'continent': 'North America',
#    'country': 'United States',
#    'country_code': 'us',
#    'county': 'Suffolk County',
#    'house_number': '83',
#    'neighbourhood': 'Uphams Corner',
#    'postcode': '02125',
#    'road': 'Mount Vernon Street',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'suburb': 'Dorchester'},
#   'confidence': 10,
#   'formatted': '83 Mount Vernon Street, Boston, MA 02125, United States of America',
#   'geometry': {'lat': 42.3215379, 'lng': -71.0561875}},
#  {'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'road',
#    '_type': 'road',
#    'continent': 'North America',
#    'country': 'United States of America',
#    'country_code': 'us',
#    'road': 'Mount Vernon St',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'town': 'Boston'},
#   'confidence': 9,
#   'formatted': 'Mount Vernon St, Boston, MA, United States of America',
#   'geometry': {'lat': 42.321558, 'lng': -71.054962}},
#  {'bounds': {'northeast': {'lat': 42.40082, 'lng': -70.748802},
#    'southwest': {'lat': 42.22788, 'lng': -71.191155}},
#   'components': {'ISO_3166-1_alpha-2': 'US',
#    'ISO_3166-1_alpha-3': 'USA',
#    'ISO_3166-2': ['US-MA'],
#    '_category': 'place',
#    '_type': 'city',
#    'continent': 'North America',
#    'country': 'United States of America',
#    'country_code': 'us',
#    'county': 'Suffolk County',
#    'state': 'Massachusetts',
#    'state_code': 'MA',
#    'town': 'Boston'},
#   'confidence': 4,
#   'formatted': 'Boston, Massachusetts, United States of America',
#   'geometry': {'lat': 42.35843, 'lng': -71.05977}}]

# %% [markdown]
# Just the first 2 results both have the same address once we constrain to Boston

# %% [markdown]
# ![first result](https://matrix.mit.edu/media/EOWgbQUfzMgssslXNvSdGids)
#
# Only the first result is identified (reversed geocoded) by Google Maps as our desired address.
#
# ![second result](https://matrix.mit.edu/media/qijfNUMXxXMmaawtNYuOSAaV)

# %% [markdown]
# Since we only care about the coordinates and address, let's have a convenience function for this.

# %%
def geocode(addr):
    results = geocoder.geocode(addr, countrycode='us', no_annotations=1)
    return [
        (result['formatted'], (result['geometry']['lat'], result['geometry']['lng']))
        for result in results
    ]

# %%
geocode(addr1)
# Out:
# [('83 Mount Vernon Street, Boston, MA 02108, United States of America',
#   (42.3584628, -71.0673552)),
#  ('83 Mount Vernon Street, New Bedford, MA 02746, United States of America',
#   (41.6520262, -70.9401207)),
#  ('83 Mount Vernon Street, Somerville, MA 02145, United States of America',
#   (42.3826346, -71.0817058)),
#  ('83 Mount Vernon Street, Malden Centre, Malden, MA 02148, United States of America',
#   (42.4321091, -71.0626237)),
#  ('83 Mount Vernon Street, Wyoming, Melrose, MA 02176, United States of America',
#   (42.4493622, -71.0639848)),
#  ('81;83 Mount Vernon Street, Lowell, MA 01854, United States of America',
#   (42.646815, -71.3259686)),
#  ('83 Mount Vernon Street, Mount Vernon, Montgomery County, GA 30445, United States of America',
#   (32.1795359, -82.5952588)),
#  ('83 Mount Vernon Street, Detroit, MI 48202, United States of America',
#   (42.3760953, -83.076043)),
#  ('83 Mount Vernon Street, Chandler Hill, Worcester, MA 01605, United States of America',
#   (42.2761316, -71.7879753))]

# %%
geocode(clean_address(addr1))
# Out:
# [('83 Mount Vernon Street, Boston, MA 02108, United States of America',
#   (42.3584628, -71.0673552)),
#  ('83 Mount Vernon Street, Boston, MA 02129, United States of America',
#   (42.37478, -71.0581028)),
#  ('83 Mount Vernon Street, Boston, MA 02135, United States of America',
#   (42.3473389, -71.1568004)),
#  ('83 Mount Vernon Street, Boston, MA 02132, United States of America',
#   (42.2849704, -71.1600953)),
#  ('83 Mount Vernon Street, Boston, MA 02125, United States of America',
#   (42.3215379, -71.0561875)),
#  ('Mount Vernon St, Boston, MA, United States of America',
#   (42.321558, -71.054962)),
#  ('Boston, Massachusetts, United States of America', (42.35843, -71.05977))]

# %% [markdown]
# Let's try the other addresses:

# %%
geocode(addr2)
# Out:
# [('Jamaica Plain, Massachusetts, United States of America',
#   (42.308353, -71.100431)),
#  ('Suffolk County, MA 02130, United States of America', (42.3126, -71.1115))]

# %% [markdown]
# It seems like it doesn't like the format.

# %%
print(clean_address(addr2_chopped))
geocode(clean_address(addr2_chopped))
# Out:
# FOREST HILLS ST & GLEN RD, Boston, MA
# [('Boston, Massachusetts, United States of America', (42.312169, -71.066139)),
#  ('Boston, Massachusetts, United States of America', (42.35843, -71.05977))]

# %% [markdown]
# wow that is so unspecific

# %%
# Let's try to manually correct the address
addr2_corrected = "FOREST HILLS ST & GLEN RD, JAMAICA PLAIN, MA 02130, UNITED STATES"
geocode(addr2_corrected)
# Out:
# [('Jamaica Plain, Massachusetts, United States of America',
#   (42.308353, -71.100431)),
#  ('Suffolk County, MA 02130, United States of America', (42.3126, -71.1115))]

# %% [markdown]
# At least it says it's in Jamaica Plain, but that is quite unspecific still. I guess OpenCage is not good at this type of address (intersection between 2 addresses).

# %% [markdown]
# Let's try the third address

# %%
geocode(addr3_chopped)
# Out:
# []

# %% [markdown]
# No results, forgot to add the Boston.

# %%
geocode(clean_address(addr3_chopped))
# Out:
# [('Boston, Massachusetts, United States of America', (42.347549, -71.103523))]

# %% [markdown]
# RIP.

# %%
geocode(addr3)
# Out:
# [('Boston, Massachusetts, United States of America', (42.347549, -71.103523)),
#  ('Suffolk County, MA 02215, United States of America', (42.3471, -71.1027))]

# %% [markdown]
# Okay, in Google Maps it is *sort of* close to the second street (Mountfort St).
#
# And for the second address it does sort of reach the two named addresses.

# %% [markdown]
# > FOREST HILLS ST & GLEN RD, JAMAICA PLAIN, MA 02130, UNITED STATES
#
# ![address 3](https://matrix.mit.edu/media/QLXITettpqgdjcHQBOPKHVAX)
